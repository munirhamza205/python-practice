# %%
b = "hello world!"
print(b[2:5])
# Out:
# llo

# %%
b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %%
b = "Hello, World!"
print(b[2:])
# Out:
# llo, World!

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl
