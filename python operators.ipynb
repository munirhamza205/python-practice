# %%
print(10+5)
# Out:
# 15

# %%
#arithmetic
x = 5
y = 10
print(x+y)
# Out:
# 15

# %%
x = 5
y = 3
print(x-y)
# Out:
# 2

# %%
x = 2
y = 6
print(x*y)
# Out:
# 12

# %%
x = 12
y = 2
print(x/y)
# Out:
# 6.0

# %%
x = 5
y = 2
print(x%y)
# Out:
# 1

# %%
x = 5
y = 3
print(x**y)
# Out:
# 125

# %%
x = 5
y = 3
print(x//y)
# Out:
# 1

# %%
#assignment operator
x = 5
print(x)
# Out:
# 5

# %%
x+=3
print(x)
# Out:
# 0.0

# %%
x-=3
print(x)
# Out:
# -3.0

# %%
x*=3
print(x)
# Out:
# 0.0

# %%
x/=3
print(x)
# Out:
# 0.0

# %%
x%=3
print(x)
# Out:
# 0

# %%
x**=3
print(x)
# Out:
# 0

# %%
x//=3
print(x)
# Out:
# 0

# %%
x&=4
print(x)
# Out:
# 4

# %%
x|=3
print(x)
# Out:
# 7

# %%
x^=3
print(x)
# Out:
# 4

# %%
x>>=3
print(x)

# %%
x<<=3
print(x)
# Out:
# 32

# %%
print(x := 3)
# Out:
# 3

# %%
#comparison operators
x = 5
y = 6
print(x == y)
# Out:
# False

# %%
x = 5
y = 6
print(x != y)
# Out:
# True

# %%
x = 5
y = 6
print(x > y)
# Out:
# False

# %%
#logical operators
x = 5
y = 6
print(x < y)
# Out:
# True

# %%
x = 5
y = 6
print(x >= y)
# Out:
# False

# %%
x = 5
y = 6
print(x <= y)
# Out:
# True

# %%
#python logical operators
x = 5
print(x > 3 and x < 10)
# Out:
# True

# %%
x = 5
print(x > 3 or x < 10)
# Out:
# True

# %%
x = 5
print(not(x > 3 and x < 10))
# Out:
# False

# %%
#python identity operators
x = ["apple", "banana"]
y = ["apple", "banana"]
z =  x
print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %%
#python identity operators
x = ["apple", "banana"]
y = ["apple", "banana"]
z =  x
print(x is not z)
print(x is not y)
print(x != y)
# Out:
# False
# True
# False
