# %%
my_list  = ["apple", "banana", "cherry"]
print(my_list)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
print(len(thislist))
# Out:
# ['apple', 'banana', 'cherry']
# 3

# %%
list1 = ["apple","banana", "cherry"]
list2 = [1,3,5,4,7,8]
list3 = [True, False, True]

# %%
list1 = ["abc", 34, "male", True, 40]
print(list1)
# Out:
# ['abc', 34, 'male', True, 40]

# %%
mylist = ["apple", "banana", "cherry"]
print(type(mylist))
# Out:
# <class 'list'>

# %%
thislist = list(("apple", "banana", "cherry"))   # not the doubble round brackets
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']
