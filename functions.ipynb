# %%
def my_function():
  print("hello from a function")

# %%
def my_function(frame):
  print(frame + "refsnes")
my_function("email")
my_function("twitter")
my_function("instagram")
# Out:
# emailrefsnes
# twitterrefsnes
# instagramrefsnes

# %%
# calling a function
def my_function():
  print("hello from a function")

# this space matters

my_function()
# Out:
# hello from a function

# %%
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")

# %%
def my_function(framename):
  print(framename + "refsnes")

my_function("email")
my_function("twitter")
my_function("instagram")
# Out:
# emailrefsnes
# twitterrefsnes
# instagramrefsnes

# %%
def my_function(count=0): #Added a count parameter to keep track of recursion depth
  if count >= 5:  # Setting a limit to the recursion depth
    return
  print("hello from a function")
  my_function(count + 1) # incrementing count with each recursive call

# %%
def my_function(framename, lname):
  print(framename + "refsnes")
  print(lname + "smith")

# Provide both arguments when calling the function
my_function("email", "ExampleLname") # Added second argument
my_function("twitter", "AnotherLname") # Added second argument
my_function("instagram", "YetAnotherLname") # Added second argument
# Out:
# emailrefsnes
# ExampleLnamesmith
# twitterrefsnes
# AnotherLnamesmith
# instagramrefsnes
# YetAnotherLnamesmith

# %%
def my_function(fname, lname):
  print(fname + " " + lname)

# calling the function
my_function("email", "refsnes")
# Out:
# email refsnes

# %%
# no of arguments
def my_function(*kids):
  print("the youngest child is " + kids[2])
  print("the youngest child is " + kids[1])
  print("the youngest child is " + kids[0])

# calling the function
my_function("email", "tobias", "linus")
# Out:
# the youngest child is linus
# the youngest child is tobias
# the youngest child is email

# %%
def my_function(**kid):
  print("His last name is " + kid["lname"])

my_function(fname = "Tobias", lname = "Refsnes")

# %%
def my_function(**kid):
  print("his last name is " + kid["lname"])
  print("his last name is " + kid["fname"])

my_function(fname = "tobias", lname = "refsnes")
# Out:
# his last name is refsnes
# his last name is tobias

# %%
def my_function(country = "norway"):
  print("I am from " + country)
  print("I am from " + country)

my_function("sweden")
my_function("india")
my_function()
my_function()
# Out:
# I am from sweden
# I am from sweden
# I am from india
# I am from india
# I am from norway
# I am from norway
# I am from norway
# I am from norway

# %%
def my_function(food):
  for x in food:
    print(x)

fruits = ["apple", "banana", "cherry"]
my_function(fruits)
# Out:
# apple
# banana
# cherry

# %%
def my_function(x):
  return 5 * x

print(my_function(3))
print(my_function(5))
print(my_function(9))
# Out:
# 15
# 25
# 45

# %%
def my_function():
  pass
print("hello")
my_function()
# Out:
# hello

# %%
#Positional-Only Arguments
#You can specify that a function can have ONLY positional arguments, or ONLY keyword arguments.

#To specify that a function can have only positional arguments, add , / after the arguments:

def my_function(x, /):
  print(x)

my_function(3)

# %%
def my_function(x, /):
  print(x)

my_function(3)
# Out:
# 3

# %%
def my_function(x):
   print(x)

my_function(x = 3)
# Out:
# 3

# %%
def my_function(*, x):
  print(x)

my_function(x = 3)
# Out:
# 3

# %%
def my_function(a, b, /, *, c, d):
  print(a + b + c + d)

my_function(5, 6, c = 7, d = 8

# %%
def my_function(a, b, /, *, c, d):
  print(a+b+c+d)

def my_function(a=3, b=4, c=6, d=10):
  pass

# %%
#Recursion Example

def tri_recursion(k):
  if(k > 0):
    result = k + tri_recursion(k - 1)
    print(result)
  else:
    result = 0
  return result

print("\n\nRecursion Example Results")
tri_recursion(6)
# Out:
# Recursion Example Results
# 1
# 3
# 6
# 10
# 15
# 21
# 21

# %%
def tri_recursion(k):
  if(k > 0):
    result = k + tri_recursion(k-1)
    print(result)
  else:
    result = 0
  return result

print("\n\nRecursion Example Results")
tri_recursion(6)
# Out:
# Recursion Example Results
# 1
# 3
# 6
# 10
# 15
# 21
# 21
