# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)

# %%
a = 200
b = 33

if b > a:
  print("b is grater than a")
else:
  print("b is not grater than a")
# Out:
#   File "<ipython-input-17-4ea98fa7e8b4>", line 6
#     else;
#         ^
# SyntaxError: expected ':'

# %%
print(bool("hello"))
print(bool(15))
# Out:
# True
# True

# %%
x = "hello"
y = 15
print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
bool("abc")
bool(123)
bool(["apple", "banana", "cherry"])
# Out:
# True

# %%
bool("false")
bool("none")
bool(0)
bool("")
bool(())
bool([])
bool({})
# Out:
# False

# %%
class myclass():
  def __len__(self):
    return 0
myobject = myclass()
print(bool(myobject))
# Out:
# False

# %%
def myFunction():
  return true
  print(myFunction())
  if myfunction():
    print("yes!")
  else:
      print("no!")

# %%
x = 200
print(isinstance(x, int))
# Out:
# True
